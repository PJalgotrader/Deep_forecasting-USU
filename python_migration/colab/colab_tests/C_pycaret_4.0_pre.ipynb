# %% [markdown]
# # Colab test C — pycaret 4.0 pre-release
#
# Expected: install succeeds, but `TSForecastingExperiment` and the functional API no longer exist.
#
# **Run this in a fresh Colab runtime** (Runtime → Disconnect and delete runtime, then Run all).

# %% [markdown]
# ## 1. Runtime before install

# %%
import sys, importlib.metadata as md
print("Python:", sys.version.split()[0])
for p in ["numpy","pandas","scikit-learn","scipy","statsmodels","sktime","matplotlib","pycaret","pycaret-core"]:
    try: print(f"  {p:14s} {md.version(p)}")
    except md.PackageNotFoundError: print(f"  {p:14s} (not installed)")
# Out:
# Python: 3.13.15
#   numpy          2.1.3
#   pandas         2.2.3
#   scikit-learn   1.6.1
#   scipy          1.16.3
#   statsmodels    0.15.0
#   sktime         (not installed)
#   matplotlib     3.10.0
#   pycaret        (not installed)
#   pycaret-core   (not installed)

# %% [markdown]
# ## 2. Install the pre-release

# %%
# !pip install -q --pre "pycaret[timeseries]"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.8/831.8 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.9/688.9 kB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.0/269.0 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 80.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.3/165.3 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 5.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.39.0 which is incompatible.

# %% [markdown]
# ## 3. What survived from 3.x?

# %%
import pycaret, pycaret.time_series as ts
print("pycaret", pycaret.__version__)
print("exports:", [n for n in dir(ts) if not n.startswith("_")])
print("TSForecastingExperiment:", hasattr(ts, "TSForecastingExperiment"))
print("functional setup():   ", hasattr(ts, "setup"))
# Out:
# pycaret 4.0.0a8
# exports: ['TimeSeriesExperiment']
# TSForecastingExperiment: False
# functional setup():    False

# %% [markdown]
# ## 4. First cell of every course notebook

# %%
from pycaret.time_series import *
exp = TSForecastingExperiment()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1360/2872756603.py in <cell line: 0>()
#       1 from pycaret.time_series import *
# ----> 2 exp = TSForecastingExperiment()
#
# NameError: name 'TSForecastingExperiment' is not defined
