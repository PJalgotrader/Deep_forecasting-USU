# %% [markdown]
# ### Prof. Pedram Jahangiry
#
# You need to make a copy to your own Google drive if you want to edit the original notebook! Start by opening this notebook on Colab 👇
#
# <a href="https://colab.research.google.com/github/PJalgotrader/Deep_forecasting-USU/blob/main/Lectures%20and%20codes/Module%205-%20Machine%20Learning%20Forecasting/Module5-DT_intuition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
#
# ![logo](https://upload.wikimedia.org/wikipedia/commons/4/44/Huntsman-Wordmark-with-USU-Blue.gif#center)
#
#
# ## 🔗 Links
#
# [![linkedin](https://img.shields.io/badge/LinkedIn-0A66C2?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/pedram-jahangiry-cfa-5778015a)
#
# [![Youtube](https://img.shields.io/badge/youtube_channel-1DA1F2?style=for-the-badge&logo=youtube&logoColor=white&color=FF0000)](https://www.youtube.com/channel/UCNDElcuuyX-2pSatVBDpJJQ)
#
# [![Twitter URL](https://img.shields.io/twitter/url/https/twitter.com/PedramJahangiry.svg?style=social&label=Follow%20%40PedramJahangiry)](https://twitter.com/PedramJahangiry)
#
#
# ---

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv", index_col="Month")
data.index = pd.to_datetime(data.index)
data.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# ## Making supervised ML data

# %%
test_period = 12
train_period = len(data) - test_period

print(f"Train period: {train_period}")
print(f"Test period: {test_period}")
# Out:
# Train period: 132
# Test period: 12

# %%
train = data.iloc[:train_period]
test = data.iloc[train_period:]

# plotting the train and test data with different colors
plt.figure(figsize=(12, 8))
plt.plot(train, label='Train')
plt.plot(test, label='Test')
plt.title('Train and Test Data')
plt.xlabel('Month')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()

# %%
train.index[-1]
# Out:
# Timestamp('1959-12-01 00:00:00')

# %%
# A Boolean series indicating which rows of the DataFrame data belong to each set (train, test)
train_indicator = (data.index <= train.index[-1])
test_indicator =  (data.index > train.index[-1])

test_indicator
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
# creating feature space X and target variable y for the training and test datasets
series = data['Passengers'].dropna().to_numpy()
series
# Out:
# array([112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115,
#        126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140, 145, 150,
#        178, 163, 172, 178, 199, 199, 184, 162, 146, 166, 171, 180, 193,
#        181, 183, 218, 230, 242, 209, 191, 172, 194, 196, 196, 236, 235,
#        229, 243, 264, 272, 237, 211, 180, 201, 204, 188, 235, 227, 234,
#        264, 302, 293, 259, 229, 203, 229, 242, 233, 267, 269, 270, 315,
#        364, 347, 312, 274, 237, 278, 284, 277, 317, 313, 318, 374, 413,
#        405, 355, 306, 271, 306, 315, 301, 356, 348, 355, 422, 465, 467,
#        404, 347, 305, 336, 340, 318, 362, 348, 363, 435, 491, 505, 404,
#        359, 310, 337, 360, 342, 406, 396, 420, 472, 548, 559, 463, 407,
#        362, 405, 417, 391, 419, 461, 472, 535, 622, 606, 508, 461, 390,
#        432], dtype=int64)

# %%
len(series)
# Out:
# 144

# %%
Tx = 2 # Number of lags! using the past Tx observations to forecast the next one.
Ty = 1 #  Forecasting Ty outputs at once
X = np.array([series[t:t+Tx] for t in range(len(series) - Tx-Ty+1)])
Y = np.array([series[t+Tx: t+Tx+Ty] for t in range(len(series) - Tx-Ty+1)])
N = len(X)

print("X:", X.shape, "Y:", Y.shape, "N:", N)
# Out:
# X: (142, 2) Y: (142, 1) N: 142

# %% [markdown]
# To understand it better, try a simple series = np.arange(7) with Tx=2 and Ty=1 and print X and Y

# %%
#series = np.arange(7)
#series

# %%
X
# Out:
# array([[112, 118],
#        [118, 132],
#        [132, 129],
#        [129, 121],
#        [121, 135],
#        [135, 148],
#        [148, 148],
#        [148, 136],
#        [136, 119],
#        [119, 104],
#        [104, 118],
#        [118, 115],
#        [115, 126],
#        [126, 141],
#        [141, 135],
#        [135, 125],
#        [125, 149],
#        [149, 170],
#        [170, 170],
#        [170, 158],
#        [158, 133],
#        [133, 114],
#        [114, 140],
#        [140, 145],
#        [145, 150],
#        [150, 178],
#        [178, 163],
#        [163, 172],
#        [172, 178],
#        [178, 199],
#        [199, 199],
#        [199, 184],
#        [184, 162],
#        [162, 146],
#        [146, 166],
#        [166, 171],
#        [171, 180],
#        [180, 193],
#        [193, 181],
#        [181, 183],
#        [183, 218],
#        [218, 230],
#        [230, 242],
#        [242, 209],
#        [209, 191],
#        [191, 172],
#        [172, 194],
#        [194, 196],
#        [196, 196],
#        [196, 236],
#        [236, 235],
#        [235, 229],
#        [229, 243],
#        [243, 264],
#        [264, 272],
#        [272, 237],
#        [237, 211],
#        [211, 180],
#        [180, 201],
#        [201, 204],
#        [204, 188],
#        [188, 235],
#        [235, 227],
#        [227, 234],
#        [234, 264],
#        [264, 302],
#        [302, 293],
#        [293, 259],
#        [259, 229],
#        [229, 203],
#        [203, 229],
#        [229, 242],
#        [242, 233],
#        [233, 267],
#        [267, 269],
#        [269, 270],
#        [270, 315],
#        [315, 364],
#        [364, 347],
#        [347, 312],
#        [312, 274],
#        [274, 237],
#        [237, 278],
#        [278, 284],
#        [284, 277],
#        [277, 317],
#        [317, 313],
#        [313, 318],
#        [318, 374],
#        [374, 413],
#        [413, 405],
#        [405, 355],
#        [355, 306],
#        [306, 271],
#        [271, 306],
#        [306, 315],
#        [315, 301],
#        [301, 356],
#        [356, 348],
#        [348, 355],
#        [355, 422],
#        [422, 465],
#        [465, 467],
#        [467, 404],
#        [404, 347],
#        [347, 305],
#        [305, 336],
#        [336, 340],
#        [340, 318],
#        [318, 362],
#        [362, 348],
#        [348, 363],
#        [363, 435],
#        [435, 491],
#        [491, 505],
#        [505, 404],
#        [404, 359],
#        [359, 310],
#        [310, 337],
#        [337, 360],
#        [360, 342],
#        [342, 406],
#        [406, 396],
#        [396, 420],
#        [420, 472],
#        [472, 548],
#        [548, 559],
#        [559, 463],
#        [463, 407],
#        [407, 362],
#        [362, 405],
#        [405, 417],
#        [417, 391],
#        [391, 419],
#        [419, 461],
#        [461, 472],
#        [472, 535],
#        [535, 622],
#        [622, 606],
#        [606, 508],
#        [508, 461],
#        [461, 390]], dtype=int64)

# %%
Y
# Out:
# array([[132],
#        [129],
#        [121],
#        [135],
#        [148],
#        [148],
#        [136],
#        [119],
#        [104],
#        [118],
#        [115],
#        [126],
#        [141],
#        [135],
#        [125],
#        [149],
#        [170],
#        [170],
#        [158],
#        [133],
#        [114],
#        [140],
#        [145],
#        [150],
#        [178],
#        [163],
#        [172],
#        [178],
#        [199],
#        [199],
#        [184],
#        [162],
#        [146],
#        [166],
#        [171],
#        [180],
#        [193],
#        [181],
#        [183],
#        [218],
#        [230],
#        [242],
#        [209],
#        [191],
#        [172],
#        [194],
#        [196],
#        [196],
#        [236],
#        [235],
#        [229],
#        [243],
#        [264],
#        [272],
#        [237],
#        [211],
#        [180],
#        [201],
#        [204],
#        [188],
#        [235],
#        [227],
#        [234],
#        [264],
#        [302],
#        [293],
#        [259],
#        [229],
#        [203],
#        [229],
#        [242],
#        [233],
#        [267],
#        [269],
#        [270],
#        [315],
#        [364],
#        [347],
#        [312],
#        [274],
#        [237],
#        [278],
#        [284],
#        [277],
#        [317],
#        [313],
#        [318],
#        [374],
#        [413],
#        [405],
#        [355],
#        [306],
#        [271],
#        [306],
#        [315],
#        [301],
#        [356],
#        [348],
#        [355],
#        [422],
#        [465],
#        [467],
#        [404],
#        [347],
#        [305],
#        [336],
#        [340],
#        [318],
#        [362],
#        [348],
#        [363],
#        [435],
#        [491],
#        [505],
#        [404],
#        [359],
#        [310],
#        [337],
#        [360],
#        [342],
#        [406],
#        [396],
#        [420],
#        [472],
#        [548],
#        [559],
#        [463],
#        [407],
#        [362],
#        [405],
#        [417],
#        [391],
#        [419],
#        [461],
#        [472],
#        [535],
#        [622],
#        [606],
#        [508],
#        [461],
#        [390],
#        [432]], dtype=int64)

# %%
X[:-test_period].shape
# Out:
# (130, 2)

# %%
X[-test_period:].shape
# Out:
# (12, 2)

# %%
Xtrain, Ytrain = X[:-test_period], Y[:-test_period]
Xtest, Ytest = X[-test_period:], Y[-test_period:]

# printing shapes
print(Xtrain.shape, Ytrain.shape, Xtest.shape, Ytest.shape)
# Out:
# (130, 2) (130, 1) (12, 2) (12, 1)

# %%
# training a simple decision tree model with depth 10
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error

dt_model = DecisionTreeRegressor()
dt_model.fit(Xtrain, Ytrain)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## One step ahead forecast
#
# At each point in time (either in train or test set) we have access to the past Tx lags actual observations.

# %%
train_indicator[:Tx] = False # the first Tx values are not predictable.
# because we need Tx lags to predict the next value

# %%
train_indicator
# Out:
# array([False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
test_indicator
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
dt_1step_train_forcast = dt_model.predict(Xtrain)
dt_1step_test_forecast = dt_model.predict(Xtest)

# %%
dt_1step_train_forcast.shape
# Out:
# (130,)

# %%
dt_1step_test_forecast.shape
# Out:
# (12,)

# %%
# plotting one step ahead forecast

data.loc[train_indicator, '1step_train_forecast'] = dt_1step_train_forcast
data.loc[test_indicator, '1step_test_forecast'] = dt_1step_test_forecast
data.head()
# Out:
#             Passengers  1step_train_forecast  1step_test_forecast
# Month
# 1949-01-01         112                   NaN                  NaN
# 1949-02-01         118                   NaN                  NaN
# 1949-03-01         132                 132.0                  NaN
# 1949-04-01         129                 129.0                  NaN
# 1949-05-01         121                 121.0                  NaN

# %%
data.tail()
# Out:
#             Passengers  1step_train_forecast  1step_test_forecast
# Month
# 1960-08-01         606                   NaN                463.0
# 1960-09-01         508                   NaN                463.0
# 1960-10-01         461                   NaN                463.0
# 1960-11-01         390                   NaN                407.0
# 1960-12-01         432                   NaN                347.0

# %%
# plot 1-step forecast
data[['Passengers', '1step_train_forecast', '1step_test_forecast']].plot(figsize=(15, 5))
plt.title('1-step ahead forecast')
plt.show()

# %% [markdown]
# ## Multi-step Forecast
#
# At each point in time, we have access to the Tx lag observations only in the train set. For the test set however, we need to create the lag terms based on previous predictions, that's why we cannot use model.fit(X_test) for multi-step predictions. We need to generate a sequence of predictions for test_period steps into the future.
#
# These predictions can then be used to evaluate the performance of the model over this period.

# %%
Xtest
# Out:
# array([[362, 405],
#        [405, 417],
#        [417, 391],
#        [391, 419],
#        [419, 461],
#        [461, 472],
#        [472, 535],
#        [535, 622],
#        [622, 606],
#        [606, 508],
#        [508, 461],
#        [461, 390]], dtype=int64)

# %%
Xtest.shape
# Out:
# (12, 2)

# %%
Xtest[0].shape
# Out:
# (2,)

# %%
Xtest[0].reshape(1, -1).shape
# Out:
# (1, 2)

# %%
train.tail()
# Out:
#             Passengers
# Month
# 1959-08-01         559
# 1959-09-01         463
# 1959-10-01         407
# 1959-11-01         362
# 1959-12-01         405

# %%
Xtest[0]
# Out:
# array([362, 405], dtype=int64)

# %%
input_X = Xtest[0]
prediction = dt_model.predict(input_X.reshape(1, -1))[0]
print(prediction)
# Out:
# 435.0

# %%
test.head()
# Out:
#             Passengers
# Month
# 1960-01-01         417
# 1960-02-01         391
# 1960-03-01         419
# 1960-04-01         461
# 1960-05-01         472

# %%
input_X = np.roll(input_X, -1)
input_X[-1] = prediction
print(input_X)
# Out:
# [405 435]

# %%
multistep_predictions = []

# first test input
input_X = Xtest[0]

# Start a loop that will continue until we have the desired number of future forecasts (test_period).
while len(multistep_predictions) < test_period:
  prediction = dt_model.predict(input_X.reshape(1, -1))[0]
  
  # update the predictions list
  multistep_predictions.append(prediction)

  # update the new input
  # The input_X array, which serves as input for the next prediction, is updated. The np.roll(input_X, -1) shifts all elements of input_X one position to the left. 
  # The last element of last_x, which is now freed up, is filled with the last prediction p.
  input_X = np.roll(input_X, -1)
  input_X[-1] = prediction

# %%
multistep_predictions
# Out:
# [435.0,
#  491.0,
#  505.0,
#  404.0,
#  359.0,
#  310.0,
#  337.0,
#  360.0,
#  342.0,
#  406.0,
#  396.0,
#  420.0]

# %%
# save multi-step forecast to dataframe
data.loc[test_indicator, 'multistep_test_forecast'] = multistep_predictions
data.tail()
# Out:
#             Passengers  1step_train_forecast  1step_test_forecast  \
# Month
# 1960-08-01         606                   NaN                463.0
# 1960-09-01         508                   NaN                463.0
# 1960-10-01         461                   NaN                463.0
# 1960-11-01         390                   NaN                407.0
# 1960-12-01         432                   NaN                347.0
#
#             multistep_test_forecast
# Month
# 1960-08-01                    360.0
# 1960-09-01                    342.0
# 1960-10-01                    406.0
# 1960-11-01                    396.0
# 1960-12-01                    420.0

# %%
# plot 1-step and multi-step forecast
data[['Passengers', '1step_test_forecast', 'multistep_test_forecast']].plot(figsize=(15, 5))
plt.title('1-step and multi-step ahead forecast')
plt.show()

# %% [markdown]
# # Multi-output forecast

# %%
# Make multi-output supervised dataset
Tx = 2 # recall: using the past Tx lag observations to forecast the next one.
Ty = test_period # number of outputs forecasted at once

# Create input-output pairs
X = np.array([series[t:t+Tx] for t in range(len(series) - Tx - Ty+1)])
Y = np.array([series[t+Tx:t+Tx+Ty] for t in range(len(series) - Tx - Ty+1)])
N = len(X)

print("X:", X.shape, "Y:", Y.shape, "N:", N)
# Out:
# X: (131, 2) Y: (131, 12) N: 131

# %%
series[0:14]
# Out:
# array([112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115,
#        126], dtype=int64)

# %%
X[0]
# Out:
# array([112, 118], dtype=int64)

# %%
Y[0]
# Out:
# array([132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115, 126],
#       dtype=int64)

# %%
X[:-1].shape
# Out:
# (130, 2)

# %%
Xtrain_mo, Ytrain_mo = X[:-1], Y[:-1] 
Xtest_mo, Ytest_mo = X[-1:], Y[-1:] # this is the last observation from data which we use to forecast the future

# %%
# print the shapes
print(Xtrain_mo.shape, Ytrain_mo.shape, Xtest_mo.shape, Ytest_mo.shape)
# Out:
# (130, 2) (130, 12) (1, 2) (1, 12)

# %%
multioutput_predictions_train = DecisionTreeRegressor().fit(Xtrain_mo, Ytrain_mo).predict(Xtrain_mo)
multioutput_predictions_test = DecisionTreeRegressor().fit(Xtrain_mo, Ytrain_mo).predict(Xtest_mo) # because we are forecasting multi-output at once, we can use the model.predict(X_test)

# printing the shapes
print(multioutput_predictions_train.shape, multioutput_predictions_test.shape)
# Out:
# (130, 12) (1, 12)

# %%
multioutput_predictions_test[0]
# Out:
# array([465., 467., 404., 347., 305., 336., 340., 318., 362., 348., 363.,
#        435.])

# %%
# save multi-output forecast to dataframe
data.loc[test_indicator, 'multioutput_test_forecast'] = multioutput_predictions_test[0]
data.tail()
# Out:
#             Passengers  1step_train_forecast  1step_test_forecast  \
# Month
# 1960-08-01         606                   NaN                463.0
# 1960-09-01         508                   NaN                463.0
# 1960-10-01         461                   NaN                463.0
# 1960-11-01         390                   NaN                407.0
# 1960-12-01         432                   NaN                347.0
#
#             multistep_test_forecast  multioutput_test_forecast
# Month
# 1960-08-01                    360.0                      318.0
# 1960-09-01                    342.0                      362.0
# 1960-10-01                    406.0                      348.0
# 1960-11-01                    396.0                      363.0
# 1960-12-01                    420.0                      435.0

# %%
# plot 1-step and multi-step forecast along with multi-output forecast
data[['Passengers', '1step_test_forecast', 'multistep_test_forecast', 'multioutput_test_forecast' ]].plot(figsize=(15, 5))
plt.title('1-step, multi-step and multi-output ahead forecast')
plt.show()

# %% [markdown]
# # Forecast comparison

# %%
# MAPE
passenger_test = data.loc[test_indicator, 'Passengers']
mape1 = mean_absolute_percentage_error(passenger_test, data.loc[test_indicator, '1step_test_forecast'])
mape2 = mean_absolute_percentage_error(passenger_test, data.loc[test_indicator, 'multistep_test_forecast'])
mape3 = mean_absolute_percentage_error(passenger_test, data.loc[test_indicator, 'multioutput_test_forecast'])
print("1step_test MAE:", mape1)
print("multi-step MAE:", mape2)
print("multi-output MAE:", mape3)
# Out:
# 1step_test MAE: 0.09607627280069507
# multi-step MAE: 0.22009684778755523
# multi-output MAE: 0.2379721118458613

# %% [markdown]
# ## ML_ts_forecaster

# %%
# putting everything together for the one-step and multi-step forecasts in a function

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error


def ml_ts_forecaster(data, target, lags, fh, model, model_name):

    series = data[target].dropna().to_numpy()

    Tx = lags  
    Ty = 1 #  Forecasting Ty step ahead

    # Splitting the data
    test_period = fh
    train_period = len(data) - test_period
    train = data.iloc[:train_period]
    test = data.iloc[train_period:]

    # boolean series for train and test
    train_indicator = (data.index <= train.index[-1])
    test_indicator =  (data.index > train.index[-1])
    train_indicator[:Tx] = False # the first Tx values are not predictable.

    # making supervised data
    X = np.array([series[t:t+Tx] for t in range(len(series) - Tx-Ty+1)])
    Y = np.array([series[t+Tx+Ty-1] for t in range(len(series) - Tx-Ty+1)])
    Xtrain, Ytrain = X[:-test_period], Y[:-test_period]
    Xtest, Ytest = X[-test_period:], Y[-test_period:]

    # training the model
    model.fit(Xtrain, Ytrain)

    # one-step ahead forecast
    data.loc[train_indicator, f'{model_name}_1step_train_forecast'] = model.predict(Xtrain)
    data.loc[test_indicator, f'{model_name}_1step_test_forecast'] = model.predict(Xtest)

    # multi-step ahead forecast
    multistep_predictions = []
    input_X = Xtest[0]
    while len(multistep_predictions) < test_period:
        prediction = model.predict(input_X.reshape(1, -1))[0]
        multistep_predictions.append(prediction)
        input_X = np.roll(input_X, -1)
        input_X[-1] = prediction

    data.loc[test_indicator, f'{model_name}_multistep_test_forecast'] = multistep_predictions

    # MAPE comparison 
    mape_1step = mean_absolute_percentage_error(data.loc[test_indicator, target], data.loc[test_indicator, f'{model_name}_1step_test_forecast'])
    mape_multiple_step = mean_absolute_percentage_error(data.loc[test_indicator, target], data.loc[test_indicator, f'{model_name}_multistep_test_forecast'])
    print(f"{model_name} 1-step MAPE:", mape_1step)
    print(f"{model_name} multi-step MAPE:", mape_multiple_step)

    # plot 1-step and multi-step forecast
    data[[target, f'{model_name}_1step_test_forecast', f'{model_name}_multistep_test_forecast']].plot(figsize=(15, 5))
    plt.title('1-step and multi-step ahead forecast')
    plt.show()

    return data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv", index_col="Month")
ml_ts_forecaster(data=df, target='Passengers', lags=12, fh=12, model = DecisionTreeRegressor(), model_name='dt')
# Out:
# dt 1-step MAPE: 0.05868521583579262
# dt multi-step MAPE: 0.06245955235597151
#          Passengers  dt_1step_train_forecast  dt_1step_test_forecast  \
# Month
# 1949-01         112                      NaN                     NaN
# 1949-02         118                      NaN                     NaN
# 1949-03         132                      NaN                     NaN
# 1949-04         129                      NaN                     NaN
# 1949-05         121                      NaN                     NaN
# ...             ...                      ...                     ...
# 1960-08         606                      NaN                   559.0
# 1960-09         508                      NaN                   559.0
# 1960-10         461                      NaN                   463.0
# 1960-11         390                      NaN                   463.0
# 1960-12         432                      NaN                   435.0
#
#          dt_multistep_test_forecast
# Month
# 1949-01                         NaN
# 1949-02                         NaN
# 1949-03                         NaN
# 1949-04                         NaN
# 1949-05                         NaN
# ...                             ...
# 1960-08                       559.0
# 1960-09                       559.0
# 1960-10                       463.0
# 1960-11                       463.0
# 1960-12                       463.0
#
# [144 rows x 4 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv", index_col="Month")
ml_ts_forecaster(data=df, target='Passengers', lags=12, fh=12, model = LinearRegression(), model_name='lr')
# Out:
# lr 1-step MAPE: 0.037511349261051014
# lr multi-step MAPE: 0.031428985575863495
#          Passengers  lr_1step_train_forecast  lr_1step_test_forecast  \
# Month
# 1949-01         112                      NaN                     NaN
# 1949-02         118                      NaN                     NaN
# 1949-03         132                      NaN                     NaN
# 1949-04         129                      NaN                     NaN
# 1949-05         121                      NaN                     NaN
# ...             ...                      ...                     ...
# 1960-08         606                      NaN              605.385382
# 1960-09         508                      NaN              531.731611
# 1960-10         461                      NaN              437.841621
# 1960-11         390                      NaN              421.477381
# 1960-12         432                      NaN              419.972467
#
#          lr_multistep_test_forecast
# Month
# 1949-01                         NaN
# 1949-02                         NaN
# 1949-03                         NaN
# 1949-04                         NaN
# 1949-05                         NaN
# ...                             ...
# 1960-08                  607.170592
# 1960-09                  526.877273
# 1960-10                  455.721249
# 1960-11                  403.817596
# 1960-12                  441.309646
#
# [144 rows x 4 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv", index_col="Month")
ml_ts_forecaster(data=df, target='Passengers', lags=12, fh=12, model = RandomForestRegressor(bootstrap=False), model_name='rf')
# Out:
# rf 1-step MAPE: 0.047710930663203595
# rf multi-step MAPE: 0.054043205959736246
#          Passengers  rf_1step_train_forecast  rf_1step_test_forecast  \
# Month
# 1949-01         112                      NaN                     NaN
# 1949-02         118                      NaN                     NaN
# 1949-03         132                      NaN                     NaN
# 1949-04         129                      NaN                     NaN
# 1949-05         121                      NaN                     NaN
# ...             ...                      ...                     ...
# 1960-08         606                      NaN                  553.39
# 1960-09         508                      NaN                  542.19
# 1960-10         461                      NaN                  465.18
# 1960-11         390                      NaN                  465.10
# 1960-12         432                      NaN                  432.14
#
#          rf_multistep_test_forecast
# Month
# 1949-01                         NaN
# 1949-02                         NaN
# 1949-03                         NaN
# 1949-04                         NaN
# 1949-05                         NaN
# ...                             ...
# 1960-08                      553.39
# 1960-09                      542.19
# 1960-10                      464.84
# 1960-11                      465.10
# 1960-12                      465.64
#
# [144 rows x 4 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv", index_col="Month")
df['log_Passengers'] = np.log(df['Passengers'])
ml_ts_forecaster(data=df, target='log_Passengers', lags=12, fh=12, model = RandomForestRegressor(bootstrap=False), model_name='rf')
# Out:
# rf 1-step MAPE: 0.00789287532192906
# rf multi-step MAPE: 0.0078930982452392
#          Passengers  log_Passengers  rf_1step_train_forecast  \
# Month
# 1949-01         112        4.718499                      NaN
# 1949-02         118        4.770685                      NaN
# 1949-03         132        4.882802                      NaN
# 1949-04         129        4.859812                      NaN
# 1949-05         121        4.795791                      NaN
# ...             ...             ...                      ...
# 1960-08         606        6.406880                      NaN
# 1960-09         508        6.230481                      NaN
# 1960-10         461        6.133398                      NaN
# 1960-11         390        5.966147                      NaN
# 1960-12         432        6.068426                      NaN
#
#          rf_1step_test_forecast  rf_multistep_test_forecast
# Month
# 1949-01                     NaN                         NaN
# 1949-02                     NaN                         NaN
# 1949-03                     NaN                         NaN
# 1949-04                     NaN                         NaN
# 1949-05                     NaN                         NaN
# ...                         ...                         ...
# 1960-08                6.317802                    6.317802
# 1960-09                6.292972                    6.292972
# 1960-10                6.144109                    6.143593
# 1960-11                5.993470                    5.993470
# 1960-12                6.145117                    6.146571
#
# [144 rows x 5 columns]

# %%
# KNN regressor 
from sklearn.neighbors import KNeighborsRegressor

df = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv", index_col="Month")
ml_ts_forecaster(data=df, target='Passengers', lags=12, fh=12, model = KNeighborsRegressor(), model_name='KNN')
# Out:
# KNN 1-step MAPE: 0.12878913190362845
# KNN multi-step MAPE: 0.12001244980641906
#          Passengers  KNN_1step_train_forecast  KNN_1step_test_forecast  \
# Month
# 1949-01         112                       NaN                      NaN
# 1949-02         118                       NaN                      NaN
# 1949-03         132                       NaN                      NaN
# 1949-04         129                       NaN                      NaN
# 1949-05         121                       NaN                      NaN
# ...             ...                       ...                      ...
# 1960-08         606                       NaN                    495.8
# 1960-09         508                       NaN                    439.0
# 1960-10         461                       NaN                    399.2
# 1960-11         390                       NaN                    389.4
# 1960-12         432                       NaN                    374.2
#
#          KNN_multistep_test_forecast
# Month
# 1949-01                          NaN
# 1949-02                          NaN
# 1949-03                          NaN
# 1949-04                          NaN
# 1949-05                          NaN
# ...                              ...
# 1960-08                        515.0
# 1960-09                        495.8
# 1960-10                        438.4
# 1960-11                        380.2
# 1960-12                        364.2
#
# [144 rows x 4 columns]

# %% [markdown]
# # PyCaret

# %%
# Now let's do pycaret

df = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv", index_col="Month")
df.index = pd.to_datetime(df.index).to_period('M')

from pycaret.time_series import *
exp = TSForecastingExperiment()

exp.setup(data = df, session_id = 100, fh = 12, target = 'Passengers')
# Out:
# <style type="text/css">
# #T_22774_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22774">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22774_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_22774_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22774_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22774_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_22774_row0_col1" class="data row0 col1" >100</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22774_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_22774_row1_col1" class="data row1 col1" >Passengers</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22774_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_22774_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_22774_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_22774_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_22774_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_22774_row4_col1" class="data row4 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_22774_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_22774_row5_col1" class="data row5 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_22774_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_22774_row6_col1" class="data row6 col1" >(132, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_22774_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_22774_row7_col1" class="data row7 col1" >(12, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_22774_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_22774_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_22774_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_22774_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_22774_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_22774_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_22774_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_22774_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_22774_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_22774_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_22774_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_22774_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_22774_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_22774_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_22774_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_22774_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_22774_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_22774_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_22774_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_22774_row17_col1" class="data row17 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_22774_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_22774_row18_col1" class="data row18 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_22774_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_22774_row19_col1" class="data row19 col1" >[48, 36, 11]</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_22774_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_22774_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_22774_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_22774_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_22774_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_22774_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_22774_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_22774_row23_col1" class="data row23 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_22774_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_22774_row24_col1" class="data row24 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_22774_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_22774_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_22774_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_22774_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_22774_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_22774_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_22774_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_22774_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_22774_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_22774_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22774_level0_row3

# %%
exp.compare_models()
# Out:
# <style type="text/css">
# #T_516a5 th {
#   text-align: left;
# }
# #T_516a5_row0_col0, #T_516a5_row1_col0, #T_516a5_row1_col1, #T_516a5_row1_col2, #T_516a5_row1_col3, #T_516a5_row1_col4, #T_516a5_row1_col5, #T_516a5_row1_col6, #T_516a5_row1_col7, #T_516a5_row2_col0, #T_516a5_row2_col1, #T_516a5_row2_col2, #T_516a5_row2_col3, #T_516a5_row2_col4, #T_516a5_row2_col5, #T_516a5_row2_col6, #T_516a5_row2_col7, #T_516a5_row3_col0, #T_516a5_row3_col1, #T_516a5_row3_col2, #T_516a5_row3_col3, #T_516a5_row3_col4, #T_516a5_row3_col5, #T_516a5_row3_col6, #T_516a5_row3_col7, #T_516a5_row4_col0, #T_516a5_row4_col1, #T_516a5_row4_col2, #T_516a5_row4_col3, #T_516a5_row4_col4, #T_516a5_row4_col5, #T_516a5_row4_col6, #T_516a5_row4_col7, #T_516a5_row5_col0, #T_516a5_row5_col1, #T_516a5_row5_col2, #T_516a5_row5_col3, #T_516a5_row5_col4, #T_516a5_row5_col5, #T_516a5_row5_col6, #T_516a5_row5_col7, #T_516a5_row6_col0, #T_516a5_row6_col1, #T_516a5_row6_col2, #T_516a5_row6_col3, #T_516a5_row6_col4, #T_516a5_row6_col5, #T_516a5_row6_col6, #T_516a5_row6_col7, #T_516a5_row7_col0, #T_516a5_row7_col1, #T_516a5_row7_col2, #T_516a5_row7_col3, #T_516a5_row7_col4, #T_516a5_row7_col5, #T_516a5_row7_col6, #T_516a5_row7_col7, #T_516a5_row8_col0, #T_516a5_row8_col1, #T_516a5_row8_col2, #T_516a5_row8_col3, #T_516a5_row8_col4, #T_516a5_row8_col5, #T_516a5_row8_col6, #T_516a5_row8_col7, #T_516a5_row9_col0, #T_516a5_row9_col1, #T_516a5_row9_col2, #T_516a5_row9_col3, #T_516a5_row9_col4, #T_516a5_row9_col5, #T_516a5_row9_col6, #T_516a5_row9_col7, #T_516a5_row10_col0, #T_516a5_row10_col1, #T_516a5_row10_col2, #T_516a5_row10_col3, #T_516a5_row10_col4, #T_516a5_row10_col5, #T_516a5_row10_col6, #T_516a5_row10_col7, #T_516a5_row11_col0, #T_516a5_row11_col1, #T_516a5_row11_col2, #T_516a5_row11_col3, #T_516a5_row11_col4, #T_516a5_row11_col5, #T_516a5_row11_col6, #T_516a5_row11_col7, #T_516a5_row12_col0, #T_516a5_row12_col1, #T_516a5_row12_col2, #T_516a5_row12_col3, #T_516a5_row12_col4, #T_516a5_row12_col5, #T_516a5_row12_col6, #T_516a5_row12_col7, #T_516a5_row13_col0, #T_516a5_row13_col1, #T_516a5_row13_col2, #T_516a5_row13_col3, #T_516a5_row13_col4, #T_516a5_row13_col5, #T_516a5_row13_col6, #T_516a5_row13_col7, #T_516a5_row14_col0, #T_516a5_row14_col1, #T_516a5_row14_col2, #T_516a5_row14_col3, #T_516a5_row14_col4, #T_516a5_row14_col5, #T_516a5_row14_col6, #T_516a5_row14_col7, #T_516a5_row15_col0, #T_516a5_row15_col1, #T_516a5_row15_col2, #T_516a5_row15_col3, #T_516a5_row15_col4, #T_516a5_row15_col5, #T_516a5_row15_col6, #T_516a5_row15_col7, #T_516a5_row16_col0, #T_516a5_row16_col1, #T_516a5_row16_col2, #T_516a5_row16_col3, #T_516a5_row16_col4, #T_516a5_row16_col5, #T_516a5_row16_col6, #T_516a5_row16_col7, #T_516a5_row17_col0, #T_516a5_row17_col1, #T_516a5_row17_col2, #T_516a5_row17_col3, #T_516a5_row17_col4, #T_516a5_row17_col5, #T_516a5_row17_col6, #T_516a5_row17_col7, #T_516a5_row18_col0, #T_516a5_row18_col1, #T_516a5_row18_col2, #T_516a5_row18_col3, #T_516a5_row18_col4, #T_516a5_row18_col5, #T_516a5_row18_col6, #T_516a5_row18_col7, #T_516a5_row19_col0, #T_516a5_row19_col1, #T_516a5_row19_col2, #T_516a5_row19_col3, #T_516a5_row19_col4, #T_516a5_row19_col5, #T_516a5_row19_col6, #T_516a5_row19_col7, #T_516a5_row20_col0, #T_516a5_row20_col1, #T_516a5_row20_col2, #T_516a5_row20_col3, #T_516a5_row20_col4, #T_516a5_row20_col5, #T_516a5_row20_col6, #T_516a5_row20_col7, #T_516a5_row21_col0, #T_516a5_row21_col1, #T_516a5_row21_col2, #T_516a5_row21_col3, #T_516a5_row21_col4, #T_516a5_row21_col5, #T_516a5_row21_col6, #T_516a5_row21_col7, #T_516a5_row22_col0, #T_516a5_row22_col1, #T_516a5_row22_col2, #T_516a5_row22_col3, #T_516a5_row22_col4, #T_516a5_row22_col5, #T_516a5_row22_col6, #T_516a5_row22_col7, #T_516a5_row23_col0, #T_516a5_row23_col1, #T_516a5_row23_col2, #T_516a5_row23_col3, #T_516a5_row23_col4, #T_516a5_row23_col5, #T_516a5_row23_col6, #T_516a5_row23_col7, #T_516a5_row24_col0, #T_516a5_row24_col1, #T_516a5_row24_col2, #T_516a5_row24_col3, #T_516a5_row24_col4, #T_516a5_row24_col5, #T_516a5_row24_col6, #T_516a5_row24_col7, #T_516a5_row25_col0, ...
#   text-align: left;
# }
# #T_516a5_row0_col1, #T_516a5_row0_col2, #T_516a5_row0_col3, #T_516a5_row0_col4, #T_516a5_row0_col5, #T_516a5_row0_col6, #T_516a5_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_516a5_row0_col8, #T_516a5_row1_col8, #T_516a5_row2_col8, #T_516a5_row3_col8, #T_516a5_row4_col8, #T_516a5_row5_col8, #T_516a5_row6_col8, #T_516a5_row7_col8, #T_516a5_row8_col8, #T_516a5_row9_col8, #T_516a5_row10_col8, #T_516a5_row11_col8, #T_516a5_row12_col8, #T_516a5_row13_col8, #T_516a5_row14_col8, #T_516a5_row16_col8, #T_516a5_row17_col8, #T_516a5_row18_col8, #T_516a5_row19_col8, #T_516a5_row20_col8, #T_516a5_row21_col8, #T_516a5_row22_col8, #T_516a5_row23_col8, #T_516a5_row24_col8, #T_516a5_row25_col8, #T_516a5_row26_col8, #T_516a5_row27_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_516a5_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_516a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_516a5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_516a5_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_516a5_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_516a5_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_516a5_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_516a5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_516a5_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_516a5_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_516a5_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_516a5_level0_row0" class="row_heading level0 row0" >exp_smooth</th>
#       <td id="T_516a5_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
#       <td id="T_516a5_row0_col1" class="data row0 col1" >0.5852</td>
#       <td id="T_516a5_row0_col2" class="data row0 col2" >0.6105</td>
#       <td id="T_516a5_row0_col3" class="data row0 col3" >17.1926</td>
#       <td id="T_516a5_row0_col4" class="data row0 col4" >20.1634</td>
#       <td id="T_516a5_row0_col5" class="data row0 col5" >0.0435</td>
#       <td id="T_516a5_row0_col6" class="data row0 col6" >0.0439</td>
#       <td id="T_516a5_row0_col7" class="data row0 col7" >0.8918</td>
#       <td id="T_516a5_row0_col8" class="data row0 col8" >0.5500</td>
#     </tr>
#     <tr>
#       <th id="T_516a5_level0_row1" class="row_heading level0 row1" >ets</th>
#       <td id="T_516a5_row1_col0" class="data row1 col0" >ETS</td>
#       <td id="T_516a5_row1_col1" class="data row1 col1" >0.5933</td>
#       <td id="T_516a5_row1_col2" class="data row1 col2" >0.6214</td>
#       <td id="T_516a5_row1_col3" class="data row1 col3" >17.4235</td>
#       <td id="T_516a5_row1_col4" class="data row1 col4" >20.5165</td>
#       <td id="T_516a5_row1_col5" class="data row1 col5" >0.0440</td>
#       <td id="T_516a5_row1_col6" class="data row1 col6" >0.0445</td>
#       <td id="T_516a5_row1_col7" class="data row1 col7" >0.8881</td>
#       <td id="T_516a5_row1_col8" class="data row1 col8" >0.5667</td>
#     </tr>
#     <tr>
#       <th id="T_516a5_level0_row2" class="row_heading level0 row2" >et_cds_dt</th>
#       <td id="T_516a5_row2_col0" class="data row2 col0" >Extra Trees w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_516a5_row2_col1" class=
# ExponentialSmoothing(seasonal='mul', sp=12, trend='add')

# %%
# creating random forest model
rf = exp.create_model('rf_cds_dt', cross_validation=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a984">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a984_level0_col0" class="col_heading level0 col0" >MASE</th>
#       <th id="T_2a984_level0_col1" class="col_heading level0 col1" >RMSSE</th>
#       <th id="T_2a984_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_2a984_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2a984_level0_col4" class="col_heading level0 col4" >MAPE</th>
#       <th id="T_2a984_level0_col5" class="col_heading level0 col5" >SMAPE</th>
#       <th id="T_2a984_level0_col6" class="col_heading level0 col6" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a984_level0_row0" class="row_heading level0 row0" >Test</th>
#       <td id="T_2a984_row0_col0" class="data row0 col0" >0.8060</td>
#       <td id="T_2a984_row0_col1" class="data row0 col1" >0.8854</td>
#       <td id="T_2a984_row0_col2" class="data row0 col2" >24.5417</td>
#       <td id="T_2a984_row0_col3" class="data row0 col3" >30.5900</td>
#       <td id="T_2a984_row0_col4" class="data row0 col4" >0.0481</td>
#       <td id="T_2a984_row0_col5" class="data row0 col5" >0.0495</td>
#       <td id="T_2a984_row0_col6" class="data row0 col6" >0.8311</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Notice this MAPE is close to what we got from:
#
# * ml_ts_forecaster(data=df, target='Passengers', lags=12, fh=12, model = RandomForestRegressor(bootstrap=False), model_name='rf')
#
# Using sklearn, we didn't deseasonalize the data but we used more lags to capture that seasonality.

# %%
tuned_rf = exp.tune_model(rf, optimize = 'MAPE')
# Out:
# <style type="text/css">
# #T_c260d_row3_col0, #T_c260d_row3_col1, #T_c260d_row3_col2, #T_c260d_row3_col3, #T_c260d_row3_col4, #T_c260d_row3_col5, #T_c260d_row3_col6, #T_c260d_row3_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_c260d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c260d_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_c260d_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_c260d_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_c260d_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_c260d_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_c260d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_c260d_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_c260d_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c260d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c260d_row0_col0" class="data row0 col0" >1956-12</td>
#       <td id="T_c260d_row0_col1" class="data row0 col1" >0.5015</td>
#       <td id="T_c260d_row0_col2" class="data row0 col2" >0.5913</td>
#       <td id="T_c260d_row0_col3" class="data row0 col3" >14.6463</td>
#       <td id="T_c260d_row0_col4" class="data row0 col4" >19.3540</td>
#       <td id="T_c260d_row0_col5" class="data row0 col5" >0.0363</td>
#       <td id="T_c260d_row0_col6" class="data row0 col6" >0.0373</td>
#       <td id="T_c260d_row0_col7" class="data row0 col7" >0.8781</td>
#     </tr>
#     <tr>
#       <th id="T_c260d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c260d_row1_col0" class="data row1 col0" >1957-12</td>
#       <td id="T_c260d_row1_col1" class="data row1 col1" >0.8548</td>
#       <td id="T_c260d_row1_col2" class="data row1 col2" >0.8678</td>
#       <td id="T_c260d_row1_col3" class="data row1 col3" >26.1330</td>
#       <td id="T_c260d_row1_col4" class="data row1 col4" >29.4620</td>
#       <td id="T_c260d_row1_col5" class="data row1 col5" >0.0733</td>
#       <td id="T_c260d_row1_col6" class="data row1 col6" >0.0700</td>
#       <td id="T_c260d_row1_col7" class="data row1 col7" >0.7726</td>
#     </tr>
#     <tr>
#       <th id="T_c260d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c260d_row2_col0" class="data row2 col0" >1958-12</td>
#       <td id="T_c260d_row2_col1" class="data row2 col1" >0.4542</td>
#       <td id="T_c260d_row2_col2" class="data row2 col2" >0.5544</td>
#       <td id="T_c260d_row2_col3" class="data row2 col3" >12.9791</td>
#       <td id="T_c260d_row2_col4" class="data row2 col4" >18.0225</td>
#       <td id="T_c260d_row2_col5" class="data row2 col5" >0.0282</td>
#       <td id="T_c260d_row2_col6" class="data row2 col6" >0.0286</td>
#       <td id="T_c260d_row2_col7" class="data row2 col7" >0.9273</td>
#     </tr>
#     <tr>
#       <th id="T_c260d_level0_row3" class="row_heading level0 row3" >Mean</th>
#       <td id="T_c260d_row3_col0" class="data row3 col0" >NaT</td>
#       <td id="T_c260d_row3_col1" class="data row3 col1" >0.6035</td>
#       <td id="T_c260d_row3_col2" class="data row3 col2" >0.6712</td>
#       <td id="T_c260d_row3_col3" class="data row3 col3" >17.9195</td>
#       <td id="T_c260d_row3_col4" class="data row3 col4" >22.2795</td>
#       <td id="T_c260d_row3_col5" class="data row3 col5" >0.0459</td>
#       <td id="T_c260d_row3_col6" class="data row3 col6" >0.0453</td>
#       <td id="T_c260d_row3_col7" class="data row3 col7" >0.8593</td>
#     </tr>
#     <tr>
#       <th id="T_c260d_level0_row4" class="row_heading level0 row4" >SD</th>
#       <td id="T_c260d_row4_col0" class="data row4 col0" >NaT</td>
#       <td id="T_c260d_row4_col1" class="data row4 col1" >0.1787</td>
#       <td id="T_c260d_row4_col2" class="data row4 col2" >0.1399</td>
#       <td id="T_c260d_row4_col3" class="data row4 col3" >5.8476</td>
#       <td id="T_c260d_row4_col4" class="data row4 col4" >5.1078</td>
#       <td id="T_c260d_row4_col5" class="data row4 col5" >0.0196</td>
#       <td id="T_c260d_row4_col6" class="data row4 col6" >0.0178</td>
#       <td id="T_c260d_row4_col7" class="data row4 col7" >0.0645</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.0s finished

# %%
exp.plot_model(tuned_rf, plot = 'forecast', data_kwargs={'fh':12})

# %% [markdown]
# # Done!
