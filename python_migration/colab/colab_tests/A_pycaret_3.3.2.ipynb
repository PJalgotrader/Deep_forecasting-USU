# %% [markdown]
# # Colab test A — official pycaret 3.3.2
#
# Expected: install succeeds, `import pycaret` raises RuntimeError on Python 3.12.
#
# **Run this in a fresh Colab runtime** (Runtime → Disconnect and delete runtime, then Run all).

# %% [markdown]
# ## 1. Runtime before install

# %%
import sys, importlib.metadata as md
print("Python:", sys.version.split()[0])
for p in ["numpy","pandas","scikit-learn","scipy","statsmodels","sktime","matplotlib","pycaret","pycaret-core"]:
    try: print(f"  {p:14s} {md.version(p)}")
    except md.PackageNotFoundError: print(f"  {p:14s} (not installed)")
# Out:
# Python: 3.13.15
#   numpy          2.1.3
#   pandas         2.2.3
#   scikit-learn   1.6.1
#   scipy          1.16.3
#   statsmodels    0.15.0
#   sktime         (not installed)
#   matplotlib     3.10.0
#   pycaret        (not installed)
#   pycaret-core   (not installed)

# %% [markdown]
# ## 2. Install the official stable release

# %%
# !pip install -q pycaret==3.3.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 64.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 58.2 MB/s eta 0:00:00

# %% [markdown]
# ## 3. Import — this is where Colab students get stuck

# %%
import pycaret
print(pycaret.__version__)
